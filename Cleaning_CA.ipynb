# %%
import pandas as pd
df = pd.read_csv("null_states.csv")
df.head()
# Out:
#                  @timestamp  @version  \
# 0  2019-12-20T18:17:17.106Z         1
# 1  2019-12-20T18:17:16.940Z         1
# 2  2019-12-20T18:17:17.105Z         1
# 3  2019-12-20T18:17:16.938Z         1
# 4  2019-12-20T18:17:16.122Z         1
#
#                                                 _raw  \
# 0  {"worker":{"ethnicity":"Chinese","breast_size"...
# 1  {"worker":{"ethnicity":"Asian","breast_size":"...
# 2  {"worker":{"ethnicity":"Asian","breast_size":"...
# 3  {"worker":{"ethnicity":"Chinese","breast_size"...
# 4  {"worker":{"ethnicity":"Chinese","breast_size"...
#
#                           _time  \
# 0  2020-01-23T00:40:37.000+0000
# 1  2020-01-23T00:40:37.000+0000
# 2  2020-01-23T00:40:37.000+0000
# 3  2020-01-23T00:40:37.000+0000
# 4  2020-01-23T00:40:37.000+0000
#
#                                          address address_soundex  \
# 0    1121 S Higley Rd, Suite 104 Mesa, AZ, 85206        S4632352
# 1  120 Elizabeth Street New York City, NY, 10013  E4213236356235
# 2               1707 SW 22nd St Miami, FL, 33145        S5323514
# 3    10S, 648 Kingery Hwy Willowbrook, IL, 60527       S52641624
# 4            506 Ferry st Little Rock, AR, 72202      F623434626
#
#                                      addresses{}  city             county  \
# 0    1121 S Higley Rd, Suite 104 Mesa, AZ, 85206   NaN    Maricopa County
# 1  120 Elizabeth Street New York City, NY, 10013   NaN               None
# 2               1707 SW 22nd St Miami, FL, 33145   NaN  Miami-Dade County
# 3    10S, 648 Kingery Hwy Willowbrook, IL, 60527   NaN      DuPage County
# 4            506 Ferry st Little Rock, AR, 72202   NaN     Pulaski County
#
#   cribl  ... worker.build worker.ethnicity  worker.eye_color  \
# 0   yes  ...        Thick          Chinese             Brown
# 1   yes  ...      Average            Asian             Brown
# 2   yes  ...      Average            Asian             Brown
# 3   yes  ...      Average          Chinese             Brown
# 4   yes  ...      Average          Chinese             Brown
#
#    worker.hair_color  worker.hair_length  worker.height worker.implants  \
# 0              Black            Mid Back    5'0''-5'5''             0.0
# 1              Black     Shoulder Length    5'0''-5'5''             0.0
# 2              Black     Shoulder Length    5'0''-5'5''             0.0
# 3              Black                   ?    5'0''-5'5''             0.0
# 4              Black     Shoulder Length    5'0''-5'5''             0.0
#
#   worker.name worker.tattoos      zip
# 0        Nana            0.0  85206.0
# 1        Yuyu            0.0  10013.0
# 2         Amy            0.0  33145.0
# 3       Cindy            0.0  60527.0
# 4       Helen            0.0  72202.0
#
# [5 rows x 59 columns]

# %%
CA_df = df[df["address"].str.contains("CA", case = True)]

# %%
bad_rows = []
for row in list(CA_df["address"]):
    if (row.split(","))[-2] != " CA":
        bad_rows.append(row)
        
bad_rows
# Out:
# ['214-55 JAMAICA AVE Queens, NY, 11428',
#  '8635 W. US HIGHWAY 24 CASCADE 80809 Cascade, CO, 80809',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '8635 W. US HIGHWAY 24 CASCADE 80809 Cascade, CO, 80809',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '8635 W. US HIGHWAY 24 CASCADE 80809 Cascade, CO, 80809',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '8635 W. US HIGHWAY 24 CASCADE 80809 Cascade, CO, 80809',
#  '8635 W. US HIGHWAY 24 CASCADE 80809 Cascade, CO, 80809',
#  '8635 W. US HIGHWAY 24 CASCADE 80809 Cascade, CO, 80809',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '8635 W. US HIGHWAY 24 CASCADE 80809 Cascade, CO, 80809',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '8635 W. US HIGHWAY 24 CASCADE 80809 Cascade, CO, 80809',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '214-55 JAMAICA AVE Queens, NY, 11428',
#  '8635 W. US HIGHWAY 24 CASCADE 80809 Cascade, CO, 80809']

# %%
CA_df = CA_df[~CA_df["address"].isin(bad_rows)]

# %% [markdown]
# CA_df.to_csv("fixed_null.csv", index = False)

# %%
CA_og = pd.read_csv("CA_rubmaps.csv")

# %%
ca_full = pd.concat([CA_og, CA_df]).reset_index(drop=True)

# %%
ca_clean = ca_full.drop(['@timestamp', '@version', '_raw', 'address_soundex',
       'addresses{}', 'city', 'county', 'cribl','cribl_pipe', 'imb_urls{}',
              "linecount",'location_hash', 'location_id','source_id',
              'sourcetype', 'splunk_server', 'splunk_server_group',"host", "index",
       'state', 'source', "zip"], axis = 1)

# %%
female_names  = list(pd.read_csv("female.firstnames.csv", header = None)[0])

# %%
d = ca_clean[ca_clean["worker.name"].isna()]["details"].to_dict()

# %%
len(d)
# Out:
# 3499

# %%
names = []
for name in female_names:
    if type(name) is str:
        if len(name) > 2:
            names.append(name)

# %%
names = [e for e in names if e not in ["SEE", "MANY", "LADY", "MISS", "LATINA",
                                       "SOON", "LATINA", "YOUNG", "LOVE", "MAN", "ELSE"]]

# %%
def get_key(val): 
    for key, value in d.items(): 
         if val == value: 
            return key 
  
    return "key doesn't exist"

# %%
names_d = {}
for index in list(d.keys()):
    details = d.get(index)
    if type(details) is str:
        names_per_details = []
        for word in details.upper().split():
            if word in names:
                if word not in names_per_details:
                        names_per_details.append(word) 
    if len(names_per_details) > 0:
        names_d[index] = names_per_details

# %%
list(names_d.values())
# Out:
# [['ROSE'],
#  ['LISA'],
#  ['HONEY'],
#  ['SUNDAY'],
#  ['TAMMY'],
#  ['MAY'],
#  ['LILLY'],
#  ['LUCY'],
#  ['MARK'],
#  ['GOLDEN'],
#  ['LINA'],
#  ['JASMINE'],
#  ['JANUARY'],
#  ['MICHELLE'],
#  ['SASHA', 'HELEN', 'LILY'],
#  ['YUKI'],
#  ['ISIS', 'VENUS'],
#  ['JOHN', 'NGOC'],
#  ['REA'],
#  ['HANG'],
#  ['SUMMER'],
#  ['SOPHIA'],
#  ['MANDI'],
#  ['TINA'],
#  ['MAY', 'ASIA'],
#  ['SUN'],
#  ['LEA', 'LISA'],
#  ['DIAMOND'],
#  ['GOLDEN'],
#  ['MARY'],
#  ['VAN'],
#  ['SARAH', 'ROSE', 'JANET'],
#  ['SANTA'],
#  ['JACK'],
#  ['OLIVE', 'LANE'],
#  ['BEE'],
#  ['MAY'],
#  ['BELL'],
#  ['MIMI'],
#  ['LISA', 'TINA'],
#  ['MAY'],
#  ['TINA'],
#  ['MAY'],
#  ['CONNIE'],
#  ['MAY'],
#  ['MIN'],
#  ['BELL'],
#  ['JENNIFER'],
#  ['HOPE'],
#  ['HANG'],
#  ['CASSIE'],
#  ['CINDY'],
#  ['MIN'],
#  ['MAY'],
#  ['MIN', 'ROSE'],
#  ['LISA', 'GINA'],
#  ['MAGGIE'],
#  ['MAGGIE', 'LEA'],
#  ['GARNET'],
#  ['LISA', 'JULIE'],
#  ['SIERRA'],
#  ['MINDY'],
#  ['SOPHIA'],
#  ['NICOLE'],
#  ['ANGEL'],
#  ['ANGEL'],
#  ['SUSAN'],
#  ['AMY', 'DAWN'],
#  ['VERONIKA'],
#  ['MELISSA'],
#  ['DEBBIE'],
#  ['ANGEL'],
#  ['WENDY'],
#  ['TRUDY'],
#  ['BEBE'],
#  ['EDEN'],
#  ['AMY'],
#  ['TINY'],
#  ['SANDRA'],
#  ['JESSICA', 'MIN'],
#  ['ANNA'],
#  ['TANYA'],
#  ['MAY'],
#  ['AVA'],
#  ['LILY', 'LUCY'],
#  ['JENNY'],
#  ['MICHELLE'],
#  ['MIN'],
#  ['JENNY'],
#  ['MIA'],
#  ['AMY'],
#  ['LISA'],
#  ['MAY'],
#  ['WENDY'],
#  ['WENDY'],
#  ['JOHN'],
#  ['JOSE'],
#  ['CHINA'],
#  ['KITTY'],
#  ['MAY'],
#  ['SUMMER'],
#  ['CANDY'],
#  ['SUMMER'],
#  ['VELVET'],
#  ['RANDY'],
#  ['JAMES'],
#  ['LINDA'],
#  ['AIDA', 'MICHELLE'],
#  ['MARY', 'SUMMER'],
#  ['MARY', 'SUMMER'],
#  ['BOBBY'],
#  ['VAN'],
#  ['MICHELLE'],
#  ['SPRING'],
#  ['ROSE'],
#  ['ROSE'],
#  ['CRYSTAL'],
#  ['LINA'],
#  ['MAE'],
#  ['MAY'],
#  ['GALE'],
#  ['MAY'],
#  ['LINDA', 'HOPE'],
#  ['SUE'],
#  ['JACKIE'],
#  ['BELL', 'MAY'],
#  ['TRACY'],
#  ['JACKIE', 'MONA'],
#  ['SHIRLEY', 'HAN'],
#  ['LEO'],
#  ['KITTY'],
#  ['CINDY', 'LISA'],
#  ['MAY', 'MIN'],
#  ['ANGELA', 'NANCY'],
#  ['CHI'],
#  ['AMY', 'NANCY'],
#  ['SUNDAY'],
#  ['MIMI'],
#  ['JESSICA'],
#  ['ROSE'],
#  ['BELLA', 'SUMMER'],
#  ['JASMINE'],
#  ['NINA'],
#  ['LINDA'],
#  ['GRACE'],
#  ['MAY', 'BELLA'],
#  ['KIM'],
#  ['CANDY'],
#  ['IVY'],
#  ['TIFFANY', 'MIN'],
#  ['LANA'],
#  ['BELLA', 'SANDRA'],
#  ['IVY'],
#  ['BRIANNA', 'MIN'],
#  ['SALLY'],
#  ['LUCY'],
#  ['BELL'],
#  ['MERRY'],
#  ['KITTY', 'HAN', 'MIN'],
#  ['EMILY', 'KIM', 'NANCY'],
#  ['KIM'],
#  ['TRUDIE'],
#  ['STAR'],
#  ['GRACE'],
#  ['LILLY'],
#  ['MAY'],
#  ['SANDY', 'MIN'],
#  ['SANTA'],
#  ['KITTY'],
#  ['ADA', 'ANNA'],
#  ['CINDY'],
#  ['SABRINA'],
#  ['CHRISTIAN'],
#  ['CHARITY'],
#  ['LUCY'],
#  ['DEBBIE'],
#  ['MAY'],
#  ['BELL', 'MAY'],
#  ['TINA'],
#  ['MAY', 'HOPE'],
#  ['MAY'],
#  ['ELLA'],
#  ['EDEN'],
#  ['TINA'],
#  ['MIN'],
#  ['MIN'],
#  ['MIN'],
#  ['HANG'],
#  ['STAR', 'MAY'],
#  ['ELLIS'],
#  ['KITTY'],
#  ['KITTY'],
#  ['HARMONY', 'CINDY'],
#  ['STEPHANIE'],
#  ['STEPHANIE'],
#  ['JOYCE', 'MIMI'],
#  ['JAN', 'MAY'],
#  ['SUN'],
#  ['FLO'],
#  ['CINDY'],
#  ['MIN'],
#  ['LILY'],
#  ['LILY'],
#  ['SUNDAY'],
#  ['MAGNOLIA'],
#  ['BELL'],
#  ['BELL'],
#  ['KITTY'],
#  ['LILLY'],
#  ['BELL'],
#  ['ANGEL'],
#  ['JOHNNY'],
#  ['STAR'],
#  ['WILLOW'],
#  ['TINA'],
#  ['SUSAN'],
#  ['TINA'],
#  ['SEPTEMBER'],
#  ['MONA', 'IMA'],
#  ['WENDY'],
#  ['GOLDEN'],
#  ['TIFFANY'],
#  ['DENISE'],
#  ['HELEN'],
#  ['WENDY'],
#  ['BLOSSOM'],
#  ['YOKO'],
#  ['JOAN'],
#  ['CINDERELLA'],
#  ['CINDERELLA'],
#  ['CHRISTIAN'],
#  ['LISA'],
#  ['MIN'],
#  ['JIMMY'],
#  ['JUDY', 'SUSAN'],
#  ['SUNDAY'],
#  ['BELL'],
#  ['BELL'],
#  ['SUMMER'],
#  ['CHERRY'],
#  ['TINA'],
#  ['LINDA'],
#  ['JACK'],
#  ['ANNIE'],
#  ['KELLY'],
#  ['MAY'],
#  ['ANGEL'],
#  ['ALICE'],
#  ['TINA'],
#  ['MAY'],
#  ['JEN'],
#  ['AMY'],
#  ['TINA'],
#  ['WENDY'],
#  ['MAY'],
#  ['IVY'],
#  ['NADIA'],
#  ['MAY'],
#  ['MAY'],
#  ['GRACE'],
#  ['HUI', 'DONNA', 'MAY'],
#  ['JESSICA'],
#  ['NICOLE'],
#  ['MAY'],
#  ['MAY'],
#  ['SANTA', 'CLARITA'],
#  ['SUNNY'],
#  ['MAY'],
#  ['SARAH'],
#  ['MAY'],
#  ['GINA'],
#  ['LINDA'],
#  ['CANDICE'],
#  ['TINA'],
#  ['SELENA', 'MIMI'],
#  ['MIMI'],
#  ['SANTA', 'MONICA'],
#  ['SOPHIE'],
#  ['UNA'],
#  ['TIFFANY'],
#  ['JACK'],
#  ['EDA'],
#  ['HOPE'],
#  ['JENNIFER', 'MIN'],
#  ['MIN'],
#  ['JENNIFER', 'MIN'],
#  ['DREW'],
#  ['TINY'],
#  ['JUNE', 'BELL'],
#  ['HOPE'],
#  ['PENNY', 'MARIE'],
#  ['ANA'],
#  ['GRACE', 'EMILY'],
#  ['PAGE'],
#  ['MIN', 'GINA'],
#  ['NINA'],
#  ['LILY'],
#  ['CINDY'],
#  ['TRAVIS'],
#  ['MIN'],
#  ['STAR'],
#  ['LILLY'],
#  ['JOHN'],
#  ['CHINA'],
#  ['BELL'],
#  ['ANNIE'],
#  ['SON', 'MIN'],
#  ['WENDY', 'HELEN'],
#  ['ANGELA', 'MIN'],
#  ['SOO'],
#  ['JENNY'],
#  ['GOLDEN'],
#  ['SUN'],
#  ['CINDY'],
#  ['SANTA'],
#  ['LEO'],
#  ['BEVERLY'],
#  ['BEVERLY'],
#  ['ANGELES'],
#  ['BEVERLY', 'VIRGIL'],
#  ['HOPE'],
#  ['TINY'],
#  ['LISA', 'CINDY', 'TINA'],
#  ['LILY'],
#  ['TINY'],
#  ['BOK'],
#  ['GAIL'],
#  ['BELL'],
#  ['SUN', 'KITTY'],
#  ['ASIA'],
#  ['NATALIE'],
#  ['AMY'],
#  ['MAY'],
#  ['MIN'],
#  ['SUN'],
#  ['CANDY'],
#  ['LUCY'],
#  ['GABRIEL'],
#  ['MIN'],
#  ['LILY'],
#  ['LEAN'],
#  ['BLOSSOM'],
#  ['MAY'],
#  ['JENNY'],
#  ['MAY'],
#  ['SOO'],
#  ['SELINA'],
#  ['MIN'],
#  ['TINY', 'IRISH'],
#  ['SARAH'],
#  ['MERCEDES'],
#  ['HELEN', 'VIVIAN'],
#  ['AMY'],
#  ['GREGORY'],
#  ['MIN'],
#  ['MARIBEL', 'KITTY', 'MIN'],
#  ['HOPE'],
#  ['JOHANNA', 'TINY'],
#  ['TINY'],
#  ['EMMA'],
#  ['STAR'],
#  ['RUBY'],
#  ['TINA', 'JULIE'],
#  ['TINY'],
#  ['MAY'],
#  ['TRACY'],
#  ['SUNDAY'],
#  ['MAY'],
#  ['TIFFANIE'],
#  ['HOPE'],
#  ['BEE', 'ANGLE'],
#  ['GRACIE', 'MAY', 'HOPE'],
#  ['SALLY'],
#  ['SUNNY'],
#  ['LILY'],
#  ['STAR'],
#  ['KITTY'],
#  ['KITTY'],
#  ['NADA'],
#  ['ALLIE'],
#  ['LINDA'],
#  ['KITTY'],
#  ['LULU'],
#  ['MAY'],
#  ['JADE', 'HOPE'],
#  ['MIN'],
#  ['PAGE'],
#  ['HOPE'],
#  ['SUNDAY'],
#  ['NINA'],
#  ['TINA', 'HOPE'],
#  ['KITTY'],
#  ['MAY'],
#  ['CHRISTIAN'],
#  ['NANCY', 'CINDY'],
#  ['MICHELLE'],
#  ['JULIE'],
#  ['SUNSHINE'],
#  ['JIMMY'],
#  ['JESSICA'],
#  ['MIN'],
#  ['MAGNOLIA'],
#  ['BELL', 'MAGNOLIA'],
#  ['PAGE'],
#  ['ANNIE'],
#  ['CRYSTAL'],
#  ['SOFIA', 'CARLA'],
#  ['STAR'],
#  ['GABRIEL'],
#  ['IRENE'],
#  ['SHANNON'],
#  ['CINDY'],
#  ['SOPHIA'],
#  ['TRAVIS'],
#  ['VICKI'],
#  ['MAY'],
#  ['PAM', 'TANYA'],
#  ['MIN'],
#  ['MIN'],
#  ['SONG'],
#  ['JENNY'],
#  ['MAY'],
#  ['KATHY'],
#  ['MAY'],
#  ['GOLDEN'],
#  ['MAY'],
#  ['EMILY'],
#  ['TINA'],
#  ['ALISHA'],
#  ['MIN'],
#  ['MICHELLE'],
#  ['AMY', 'LINDA'],
#  ['LINDA', 'CHRISTINE', 'MAY'],
#  ['MIN'],
#  ['BELL'],
#  ['WENDY'],
#  ['HOPE'],
#  ['MAY'],
#  ['MAY'],
#  ['MIN'],
#  ['JESSICA'],
#  ['JENNY'],
#  ['MIN'],
#  ['EVA'],
#  ['HOPE'],
#  ['CHERRY'],
#  ['MIN'],
#  ['JANUARY'],
#  ['ROSE'],
#  ['SUNDAY'],
#  ['GINA'],
#  ['LILY', 'GLENDORA'],
#  ['SUN'],
#  ['LEE'],
#  ['VAN'],
#  ['MIN'],
#  ['JULIE'],
#  ['KITTY'],
#  ['IVY'],
#  ['BELLA'],
#  ['HOPE'],
#  ['NANA'],
#  ['NANA'],
#  ['STAR'],
#  ['NANA'],
#  ['APRIL'],
#  ['VENICE'],
#  ['MAI'],
#  ['MIN'],
#  ['LISA'],
#  ['HOPE'],
#  ['EMILY'],
#  ['MAI'],
#  ['LINDA', 'TINY'],
#  ['LINDA'],
#  ['DIANA'],
#  ['MIMI'],
#  ['MIMI'],
#  ['MIMI'],
#  ['MIA'],
#  ['MIN'],
#  ['IVY', 'MINDY'],
#  ['SUNDAY'],
#  ['CAROL'],
#  ['NANCY'],
#  ['AMY'],
#  ['LISA'],
#  ['LISA'],
#  ['MIN'],
#  ['BELL'],
#  ['JACK'],
#  ['ANNIE'],
#  ['SHU', 'SPRING'],
#  ['BELL'],
#  ['MIN'],
#  ['MIN'],
#  ['HOPE'],
#  ['TINA', 'KELLY', 'NELLY'],
#  ['BELL'],
#  ['LILY'],
#  ['HOPE'],
#  ['MAY'],
#  ['BELL'],
#  ['AMY'],
#  ['MIN'],
#  ['MIA'],
#  ['STAR'],
#  ['TINY'],
#  ['SUNNY'],
#  ['AMY']]

# %%
ca_clean[ca_clean.index.isin(names_d.keys())]["worker.name"] = list(names_d.values())
# Out:
# /Users/michalgolovanevsky/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for index in names_d.keys():
    ca_clean.at[index, "worker.name"] = names_d.get(index)

# %%
ca_clean[ca_clean.index.isin(names_d.keys())]["worker.name"]
# Out:
# 180         [ROSE]
# 686         [LISA]
# 969        [HONEY]
# 1319      [SUNDAY]
# 2181       [TAMMY]
#             ...
# 137793       [MIA]
# 137977      [STAR]
# 138369      [TINY]
# 139106     [SUNNY]
# 139228       [AMY]
# Name: worker.name, Length: 510, dtype: object

# %%
ca_clean
# Out:
#                                _time  \
# 0       2020-01-23T00:40:37.000+0000
# 1       2020-01-23T00:40:37.000+0000
# 2       2020-01-23T00:40:37.000+0000
# 3       2020-01-23T00:40:37.000+0000
# 4       2020-01-23T00:40:37.000+0000
# ...                              ...
# 139312  2020-01-23T00:29:11.000+0000
# 139313  2020-01-23T00:29:11.000+0000
# 139314  2020-01-23T00:29:10.000+0000
# 139315  2020-01-23T00:28:34.000+0000
# 139316  2020-01-23T00:28:17.000+0000
#
#                                                   address  \
# 0                    3769 Peralta Blvd Fremont, CA, 94536
# 1         4411 Mercury St, Suite 104 San Diego, CA, 92111
# 2                 5604 El Cajon Blvd San Diego, CA, 92115
# 3          13912 Francisquito Ave Baldwin Park, CA, 91706
# 4                   3340 Coach Ln Cameron Park, CA, 95682
# ...                                                   ...
# 139312               12128 Beach Blvd. Stanton, CA, 90680
# 139313  1535 Olympic Blvd, 2nd Flr. Walnut Creek, CA, ...
# 139314                      509 8th St Oakland, CA, 94607
# 139315                     79 Grove Ave Upland, CA, 91786
# 139316                     79 Grove Ave Upland, CA, 91786
#
#                                                   details  eventtype  \
# 0                  Came in for a massage, left with a HE.        NaN
# 1       Anna answers the phone and tells me her next a...        NaN
# 2       Dude at the reception is very chatty but nice....        NaN
# 3       Blue was the provider. She was very attractive...        NaN
# 4       Orient is the closest AMP to me but I have nev...        NaN
# ...                                                   ...        ...
# 139312                           Nice place... Looks new.        NaN
# 139313  The session felt very private to me however th...        NaN
# 139314  New in town - had a good session here. I plan ...        NaN
# 139315  Just to be clear, this is listed here as 'Pain...        NaN
# 139316  It's hard to talk when your mouth is full. Fun...        NaN
#
#         extra_tip    geo.lat    geo.lon  \
# 0              45  37.559550 -122.00554
# 1              40  32.820590 -117.14837
# 2              50  32.758680 -117.07471
# 3             100  34.067345 -117.97249
# 4              40  38.658085 -120.97239
# ...           ...        ...        ...
# 139312         60  33.786000 -117.99225
# 139313         10  37.896010 -122.06073
# 139314         40  37.800630 -122.27537
# 139315         60  34.094390 -117.62903
# 139316        100  34.094390 -117.62903
#
#                                              more_details  \
# 0       Came in for a massage, Vicki greeted me, gave ...
# 1       Came in during the lunch break and just wanted...
# 2       Massage was alright. \n\r\nI had a nice little...
# 3       Ivy spa- Korean girl Blue\n\r\nThe place was i...
# 4       Nice tits, make sure to ask her to pull them o...
# ...                                                   ...
# 139312  My first visit here was a pleasant surprise. V...
# 139313  Yoyo was attractive and certainly a girl that ...
# 139314  I am new in town and was just checking out the...
# 139315  It was a late Sunday night in a very quiet nei...
# 139316  I have been here a half dozen times now. On th...
#
#                                               name{}  paid_to_house  ...  \
# 0                                     Princess Salon             60  ...
# 1                                        Mercury Spa             30  ...
# 2                                      Miracle Oasis            100  ...
# 3                       A-1 Acupuncture\nIvy Massage             60  ...
# 4                                     Orient Massage             40  ...
# ...                                              ...            ...  ...
# 139312                Delight Day Spa\nTulip Massage             50  ...
# 139313                                   Olympic Spa             45  ...
# 139314  Telegraph Massage Center\ncoco Spa\nCoco Spa             45  ...
# 139315                                   Pain clinic             50  ...
# 139316                                   Pain clinic             50  ...
#
#        worker.breast_size worker.build worker.ethnicity worker.eye_color  \
# 0                       D      Average            Asian            Brown
# 1                       B      Average            Asian            Brown
# 2                       B      Average           Latina              NaN
# 3                       C      Average           Korean            Brown
# 4                       C      Average          Chinese            Brown
# ...                   ...          ...              ...              ...
# 139312                  C      Average       Vietnamese            Brown
# 139313                  B         Thin          Chinese            Brown
# 139314                  B      Average          Chinese            Brown
# 139315                  B      Average          Chinese              NaN
# 139316                  A      Average          Chinese            Brown
#
#         worker.hair_color  worker.hair_length  worker.height  worker.implants  \
# 0                   Black                   ?    5'0''-5'5''              0.0
# 1                   Black     Shoulder Length    5'0''-5'5''              0.0
# 2                   Black     Shoulder Length    5'0''-5'5''              0.0
# 3                   Brown                Long    5'0''-5'5''              0.0
# 4                   Black     Shoulder Length    5'0''-5'5''              0.0
# ...                   ...                 ...            ...              ...
# 139312              Black     Shoulder Length    5'0''-5'5''              0.0
# 139313              Black                Long    5'0''-5'5''              0.0
# 139314              Black     Shoulder Length    5'0''-5'5''              0.0
# 139315                Red     Shoulder Length    5'0''-5'5''              NaN
# 139316              Black                   ?    5'0''-5'5''              0.0
#
#           worker.name worker.tattoos
# 0               Vicki            0.0
# 1                Anna            0.0
# 2             Jasmine            0.0
# 3                Blue            0.0
# 4       I did not ask            0.0
# ...               ...            ...
# 139312          Kathy            0.0
# 139313           Yoyo            0.0
# 139314          Wendy            0.0
# 139315           CoCo            NaN
# 139316           Tina            0.0
#
# [139317 rows x 37 columns]
